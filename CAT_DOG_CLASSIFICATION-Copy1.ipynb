# %% [markdown]
# # Working with Custom Images
#
#
# ## The Data
#
# The dataset includes 25,000 images of cats and dogs. We will be building a classifier that works with these images and attempt to detect dogs versus cats!
#
# The pictures are numbered 0-12499 for both cats and dogs, thus we have 12,500 images of Dogs and 12,500 images of Cats. This is a huge dataset!!
#
# --------
#
# **Note: We will be dealing with real image files, NOT numpy arrays. Which means a large part of this process will be learning how to work with and deal with large groups of image files. This is too much data to fit in memory as a numpy array, so we'll need to feed it into our model in batches. **
#
# ### Visualizing the Data

# %%
import matplotlib.pyplot as plt
import cv2
# Technically not necessary in newest versions of jupyter
# %matplotlib inline

# %%
cat = cv2.imread('CATS_DOGS/CATS_DOGS/train/CAT/5.jpg')
cat = cv2.cvtColor(cat,cv2.COLOR_BGR2RGB)

# %%
type(cat)
# Out:
# numpy.ndarray

# %%
cat.shape
# Out:
# (144, 176, 3)

# %%
plt.imshow(cat)

# %%
dog= cv2.imread('CATS_DOGS/CATS_DOGS/train/DOG/5.jpg')
dog = cv2.cvtColor(dog,cv2.COLOR_BGR2RGB)

# %%
dog.shape
# Out:
# (376, 500, 3)

# %%
plt.imshow(dog)

# %% [markdown]
# ## Preparing the Data for the model
#
# There is too much data for us to read all at once in memory. We can use some built in functions in Keras to automatically process the data, generate a flow of batches from a directory, and also manipulate the images.
#
# ### Image Manipulation
#
# Its usually a good idea to manipulate the images with rotation, resizing, and scaling so the model becomes more robust to different images that our data set doesn't have. We can use the **ImageDataGenerator** to do this automatically for us. Check out the documentation for a full list of all the parameters you can use here!

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=30, # rotate the image 30 degrees
                               width_shift_range=0.1, # Shift the pic width by a max of 10%
                               height_shift_range=0.1, # Shift the pic height by a max of 10%
                               rescale=1/255, # Rescale the image by normalzing it.
                               shear_range=0.2, # Shear means cutting away part of the image (max 20%)
                               zoom_range=0.2, # Zoom in by 20% max
                               horizontal_flip=True, # Allo horizontal flipping
                               fill_mode='nearest' # Fill in missing pixels with the nearest filled value
                              )

# %%
plt.imshow(image_gen.random_transform(dog))

# %%
plt.imshow(image_gen.random_transform(dog))

# %%
plt.imshow(image_gen.random_transform(dog))

# %% [markdown]
# ### Generating many manipulated images from a directory
#
#
# In order to use .flow_from_directory, you must organize the images in sub-directories. This is an absolute requirement, otherwise the method won't work. The directories should only contain images of one class, so one folder per class of images.
#
# Structure Needed:
#
# * Image Data Folder
#     * Class 1
#         * 0.jpg
#         * 1.jpg
#         * ...
#     * Class 2
#         * 0.jpg
#         * 1.jpg
#         * ...
#     * ...
#     * Class n

# %%
image_gen.flow_from_directory('CATS_DOGS/CATS_DOGS/train')
# Out:
# Found 18743 images belonging to 2 classes.

# %%
image_gen.flow_from_directory('CATS_DOGS/CATS_DOGS/test')
# Out:
# Found 6251 images belonging to 2 classes.

# %% [markdown]
# ### Resizing Images
#
# Let's have Keras resize all the images to 150 pixels by 150 pixels once they've been manipulated.

# %%
# width,height,channels
image_shape = (150,150,3)

# %% [markdown]
# # Creating the Model

# %%
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3,3),input_shape=(150,150,3), activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=(150,150,3), activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=(150,150,3), activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())


model.add(Dense(128))
model.add(Activation('relu'))

# Dropouts help reduce overfitting by randomly turning neurons off during training.
# Here we say randomly turn off 50% of neurons.
model.add(Dropout(0.5))

# Last layer, remember its binary, 0=cat , 1=dog
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 34, 34, 64)        36928
#
#  max_pooling2d_5 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 18496)             0
#
#  dense_2 (Dense)             (None, 128)               2367616
#
#  activation_2 (Activation)   (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
#  activation_3 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 2,424,065
# Trainable params: 2,424,065
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the Model

# %%
batch_size = 16

train_image_gen = image_gen.flow_from_directory('CATS_DOGS/CATS_DOGS/train',
                                               target_size=image_shape[:2],
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 18743 images belonging to 2 classes.

# %%
test_image_gen = image_gen.flow_from_directory('CATS_DOGS/CATS_DOGS/test',
                                               target_size=image_shape[:2],
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 6251 images belonging to 2 classes.

# %%
train_image_gen.class_indices
# Out:
# {'CAT': 0, 'DOG': 1}

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
results = model.fit_generator(train_image_gen,epochs=150,
                              steps_per_epoch=150,
                              validation_data=test_image_gen,
                             validation_steps=12)
# Out:
# Epoch 1/150
# 150/150 [==============================] - 113s 746ms/step - loss: 0.6939 - accuracy: 0.5238 - val_loss: 0.6863 - val_accuracy: 0.5469
# Epoch 2/150
# 150/150 [==============================] - 101s 675ms/step - loss: 0.6949 - accuracy: 0.5200 - val_loss: 0.6901 - val_accuracy: 0.5469
# Epoch 3/150
# 150/150 [==============================] - 112s 747ms/step - loss: 0.6871 - accuracy: 0.5479 - val_loss: 0.6836 - val_accuracy: 0.5365
# Epoch 4/150
# 150/150 [==============================] - 142s 945ms/step - loss: 0.6812 - accuracy: 0.5813 - val_loss: 0.6604 - val_accuracy: 0.6094
# Epoch 5/150
# 150/150 [==============================] - 116s 771ms/step - loss: 0.6796 - accuracy: 0.5888 - val_loss: 0.7412 - val_accuracy: 0.5260
# Epoch 6/150
# 150/150 [==============================] - 144s 957ms/step - loss: 0.6703 - accuracy: 0.5892 - val_loss: 0.6284 - val_accuracy: 0.6302
# Epoch 7/150
# 150/150 [==============================] - 142s 942ms/step - loss: 0.6574 - accuracy: 0.6133 - val_loss: 0.6357 - val_accuracy: 0.6198
# Epoch 8/150
# 150/150 [==============================] - 111s 737ms/step - loss: 0.6326 - accuracy: 0.6575 - val_loss: 0.6160 - val_accuracy: 0.6667
# Epoch 9/150
# 150/150 [==============================] - 114s 757ms/step - loss: 0.6354 - accuracy: 0.6470 - val_loss: 0.5875 - val_accuracy: 0.6510
# Epoch 10/150
# 150/150 [==============================] - 120s 801ms/step - loss: 0.6233 - accuracy: 0.6596 - val_loss: 0.5971 - val_accuracy: 0.6719
# Epoch 11/150
# 150/150 [==============================] - 137s 914ms/step - loss: 0.6131 - accuracy: 0.6775 - val_loss: 0.5755 - val_accuracy: 0.6875
# Epoch 12/150
# 150/150 [==============================] - 113s 751ms/step - loss: 0.5992 - accuracy: 0.6762 - val_loss: 0.5416 - val_accuracy: 0.7396
# Epoch 13/150
# 150/150 [==============================] - 111s 738ms/step - loss: 0.5932 - accuracy: 0.6855 - val_loss: 0.5920 - val_accuracy: 0.6667
# Epoch 14/150
# 150/150 [==============================] - 116s 771ms/step - loss: 0.5799 - accuracy: 0.6996 - val_loss: 0.5444 - val_accuracy: 0.7396
# Epoch 15/150
# 150/150 [==============================] - 128s 856ms/step - loss: 0.5725 - accuracy: 0.7013 - val_loss: 0.5679 - val_accuracy: 0.6771
# Epoch 16/150
# 150/150 [==============================] - 185s 1s/step - loss: 0.5553 - accuracy: 0.7202 - val_loss: 0.5382 - val_accuracy: 0.7552
# Epoch 17/150
# 150/150 [==============================] - 201s 1s/step - loss: 0.5285 - accuracy: 0.7375 - val_loss: 0.4897 - val_accuracy: 0.7604
# Epoch 18/150
# 150/150 [==============================] - 177s 1s/step - loss: 0.5574 - accuracy: 0.7246 - val_loss: 0.4764 - val_accuracy: 0.7552
# Epoch 19/150
# 150/150 [==============================] - 171s 1s/step - loss: 0.5438 - accuracy: 0.7283 - val_loss: 0.5908 - val_accuracy: 0.6458
# Epoch 20/150
# 150/150 [==============================] - 163s 1s/step - loss: 0.5364 - accuracy: 0.7386 - val_loss: 0.5242 - val_accuracy: 0.7292
# Epoch 21/150
# 150/150 [==============================] - 178s 1s/step - loss: 0.5268 - accuracy: 0.7417 - val_loss: 0.4597 - val_accuracy: 0.7969
# Epoch 22/150
# 150/150 [==============================] - 170s 1s/step - loss: 0.5201 - accuracy: 0.7454 - val_loss: 0.5605 - val_accuracy: 0.7344
# Epoch 23/150
# 150/150 [==============================] - 166s 1s/step - loss: 0.5213 - accuracy: 0.7483 - val_loss: 0.5378 - val_accuracy: 0.7604
# Epoch 24/150
# 150/150 [==============================] - 167s 1s/step - loss: 0.5096 - accuracy: 0.7654 - val_loss: 0.5338 - val_accuracy: 0.6979
# Epoch 25/150
# 150/150 [==============================] - 155s 1s/step - loss: 0.4987 - accuracy: 0.7624 - val_loss: 0.4973 - val_accuracy: 0.7760
# Epoch 26/150
# 150/150 [==============================] - 10963s 74s/step - loss: 0.5079 - accuracy: 0.7521 - val_loss: 0.4441 - val_accuracy: 0.7865
# Epoch 27/150
# 150/150 [==============================] - 7004s 47s/step - loss: 0.4993 - accuracy: 0.7625 - val_loss: 0.4470 - val_accuracy: 0.7812
# Epoch 28/150
# 150/150 [==============================] - 169s 1s/step - loss: 0.5045 - accuracy: 0.7604 - val_loss: 0.5502 - val_accuracy: 0.7448
# Epoch 29/150
# 150/150 [==============================] - 150s 1s/step - loss: 0.4903 - accuracy: 0.7617 - val_loss: 0.4183 - val_accuracy: 0.8021
# Epoch 30/150
# 150/150 [==============================] - 150s 996ms/step - loss: 0.4719 - accuracy: 0.7746 - val_loss: 0.5247 - val_accuracy: 0.7448
# Epoch 31/150
# 150/150 [==============================] - 144s 955ms/step - loss: 0.4896 - accuracy: 0.7704 - val_loss: 0.4761 - val_accuracy: 0.7604
# Epoch 32/150
# 150/150 [==============================] - 147s 981ms/step - loss: 0.4831 - accuracy: 0.7721 - val_loss: 0.4652 - val_accuracy: 0.7656
# Epoch 33/150
# 150/150 [==============================] - 152s 1s/step - loss: 0.4728 - accuracy: 0.7858 - val_loss: 0.4950 - val_accuracy: 0.7552
# Epoch 34/150
# 150/150 [==============================] - 146s 971ms/step - loss: 0.4786 - accuracy: 0.7746 - val_loss: 0.4181 - val_accuracy: 0.8021
# Epoch 35/150
# 150/150 [==============================] - 147s 975ms/step - loss: 0.4899 - accuracy: 0.7767 - val_loss: 0.4915 - val_accuracy: 0.7656
# Epoch 36/150
# 150/150 [==============================] - 148s 983ms/step - loss: 0.4819 - accuracy: 0.7725 - val_loss: 0.4991 - val_accuracy: 0.7292
# Epoch 37/150
# 150/150 [==============================] - 154s 1s/step - loss: 0.4651 - accuracy: 0.7842 - val_loss: 0.5002 - val_accuracy: 0.7448
# Epoch 38/150
# 150/150 [==============================] - 154s 1s/step - loss: 0.4720 - accuracy: 0.7725 - val_loss: 0.4876 - val_accuracy: 0.8073
# Epoch 39/150
# 150/150 [==============================] - 155s 1s/step - loss: 0.4631 - accuracy: 0.7821 - val_loss: 0.3554 - val_accuracy: 0.8385
# Epoch 40/150
# 150/150 [==============================] - 160s 1s/step - loss: 0.4459 - accuracy: 0.7925 - val_loss: 0.3748 - val_accuracy: 0.8229
# Epoch 41/150
# 150/150 [==============================] - 165s 1s/step - loss: 0.4671 - accuracy: 0.7775 - val_loss: 0.4534 - val_accuracy: 0.7604
# Epoch 42/150
# 150/150 [==============================] - 149s 992ms/step - loss: 0.4733 - accuracy: 0.7696 - val_loss: 0.3993 - val_accuracy: 0.8125
# Epoch 43/150
# 150/150 [==============================] - 144s 955ms/step - loss: 0.4507 - accuracy: 0.7909 - val_loss: 0.4233 - val_accuracy: 0.8125
# Epoch 44/150
# 150/150 [==============================] - 153s 1s/step - loss: 0.4324 - accuracy: 0.7992 - val_loss: 0.4900 - val_accuracy: 0.7760
# Epoch 45/150
# 150/150 [==============================] - 8250s 55s/step - loss: 0.4598 - accuracy: 0.7854 - val_loss: 0.3597 - val_accuracy: 0.8698
# Epoch 46/150
# 150/150 [==============================] - 182s 1s/step - loss: 0.4528 - accuracy: 0.7933 - val_loss: 0.3930 - val_accuracy: 0.8177
# Epoch 47/150
# 150/150 [==============================] - 182s 1s/step - loss: 0.4412 - accuracy: 0.7958 - val_loss: 0.3931 - val_accuracy: 0.8281
# Epoch 48/150
# 150/150 [==============================] - 204s 1s/step - loss: 0.4344 - accuracy: 0.7975 - val_loss: 0.4387 - val_accuracy: 0.7708
# Epoch 49/150
#  50/150 [=========>....................] - ETA: 1:58 - loss: 0.4447 - accuracy: 0.7900

# %%
# model.save('cat_dog2.h5')

# %% [markdown]
# # Evaluating the Model

# %%
results.history['acc']

# %%
plt.plot(results.history['acc'])

# %%
# model.save('cat_dog_100epochs.h5')

# %% [markdown]
# # Predicting on new images

# %%
train_image_gen.class_indices

# %%
import numpy as np
from keras.preprocessing import image

dog_file = 'CATS_DOGS/CATS_DOGS/train/Dog/2.jpg'

dog_img = image.load_img(dog_file, target_size=(150, 150))

dog_img = image.img_to_array(dog_img)

dog_img = np.expand_dims(dog_img, axis=0)
dog_img = dog_img/255

# %%
prediction_prob = model.predict(dog_img)

# %%
# Output prediction
print(f'Probability that image is a dog is: {prediction_prob} ')

# %% [markdown]
# The model predicted the image as dog which is the correct prediction.
#
# # Thank you!
